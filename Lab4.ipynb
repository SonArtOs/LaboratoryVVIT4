# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data(path='mnist.npz')
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2674 - accuracy: 0.9239 - val_loss: 0.1392 - val_accuracy: 0.9593
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1168 - accuracy: 0.9660 - val_loss: 0.1027 - val_accuracy: 0.9678
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0812 - accuracy: 0.9760 - val_loss: 0.0900 - val_accuracy: 0.9702
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0601 - accuracy: 0.9815 - val_loss: 0.0944 - val_accuracy: 0.9714
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0472 - accuracy: 0.9855 - val_loss: 0.0883 - val_accuracy: 0.9728

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0883 - accuracy: 0.9728

# %%
print(f'Точность модели на тестовом наборе данных: {test_accuracy}')
# Out:
# Точность модели на тестовом наборе данных: 0.9728000164031982

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'], label='Точность на обучающем наборе данных')
plt.plot(history.history['val_accuracy'], label='Точность на тестовом наборе данных')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.show()
